# %%
#configurando o ambiente

! pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.21.2)
# Requirement already satisfied: scipy in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: Pillow in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (8.3.1)
# Requirement already satisfied: cython in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (0.29.24)
# Requirement already satisfied: matplotlib in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (3.4.3)
# Requirement already satisfied: scikit-image in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (0.18.3)
# Requirement already satisfied: keras==2.3.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (2.3.1)
# Requirement already satisfied: tensorflow==2.2.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: opencv-python in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (4.5.3.56)
# Requirement already satisfied: h5py in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (2.10.0)
# Requirement already satisfied: imgaug in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: IPython[all] in /home/avmoura-linux/.local/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (7.26.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 5)) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: networkx>=2.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from scikit-image->-r requirements.txt (line 6)) (2.6.2)
# Requirement already satisfied: imageio>=2.3.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from scikit-image->-r requirements.txt (line 6)) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from scikit-image->-r requirements.txt (line 6)) (2021.8.30)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from scikit-image->-r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: six>=1.9.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from keras==2.3.1->-r requirements.txt (line 7)) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from keras==2.3.1->-r requirements.txt (line 7)) (5.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from keras==2.3.1->-r requirements.txt (line 7)) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from keras==2.3.1->-r requirements.txt (line 7)) (1.1.2)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: gast==0.3.3 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (0.3.3)
# Requirement already satisfied: termcolor>=1.1.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: astunparse==1.6.3 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: absl-py>=0.7.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (0.13.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (0.37.0)
# Requirement already satisfied: grpcio>=1.8.6 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (1.39.0)
# Requirement already satisfied: protobuf>=3.8.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorflow==2.2.0->-r requirements.txt (line 8)) (3.17.3)
# Requirement already satisfied: Shapely in /home/avmoura-linux/.local/lib/python3.8/site-packages (from imgaug->-r requirements.txt (line 11)) (1.7.1)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/lib/python3/dist-packages (from IPython[all]->-r requirements.txt (line 12)) (4.6.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (3.0.19)
# Requirement already satisfied: pygments in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (2.9.0)
# Requirement already satisfied: setuptools>=18.5 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (58.0.2)
# Requirement already satisfied: backcall in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: pickleshare in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (0.18.0)
# Requirement already satisfied: decorator in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (5.0.9)
# Requirement already satisfied: traitlets>=4.2 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (5.0.5)
# Requirement already satisfied: matplotlib-inline in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: nose>=0.10.1; extra == "all" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (1.3.7)
# Requirement already satisfied: nbformat; extra == "all" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (5.1.3)
# Requirement already satisfied: nbconvert; extra == "all" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (6.1.0)
# Requirement already satisfied: requests; extra == "all" in /usr/lib/python3/dist-packages (from IPython[all]->-r requirements.txt (line 12)) (2.22.0)
# Requirement already satisfied: qtconsole; extra == "all" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (5.1.1)
# Requirement already satisfied: ipyparallel; extra == "all" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (8.1.0)
# Requirement already satisfied: testpath; extra == "all" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (0.5.0)
# Requirement already satisfied: ipywidgets; extra == "all" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (7.6.3)
# Requirement already satisfied: Sphinx>=1.3; extra == "all" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (4.3.2)
# Requirement already satisfied: notebook; extra == "all" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (6.4.3)
# Requirement already satisfied: ipykernel; extra == "all" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from IPython[all]->-r requirements.txt (line 12)) (6.1.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0->-r requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0->-r requirements.txt (line 8)) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0->-r requirements.txt (line 8)) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0->-r requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0->-r requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: wcwidth in /home/avmoura-linux/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython[all]->-r requirements.txt (line 12)) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from jedi>=0.16->IPython[all]->-r requirements.txt (line 12)) (0.8.2)
# Requirement already satisfied: ipython-genutils in /home/avmoura-linux/.local/lib/python3.8/site-packages (from traitlets>=4.2->IPython[all]->-r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: jupyter-core in /home/avmoura-linux/.local/lib/python3.8/site-packages (from nbformat; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/lib/python3/dist-packages (from nbformat; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (3.2.0)
# Requirement already satisfied: jinja2>=2.4 in /usr/lib/python3/dist-packages (from nbconvert; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (2.10.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in /home/avmoura-linux/.local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: bleach in /home/avmoura-linux/.local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (4.0.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/lib/python3/dist-packages (from nbconvert; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (0.3)
# Requirement already satisfied: defusedxml in /home/avmoura-linux/.local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.4.3)
# Requirement already satisfied: jupyter-client>=4.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from qtconsole; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (6.1.12)
# Requirement already satisfied: qtpy in /home/avmoura-linux/.local/lib/python3.8/site-packages (from qtconsole; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.9.0)
# Requirement already satisfied: pyzmq>=17.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from qtconsole; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (22.2.1)
# Requirement already satisfied: tqdm in /home/avmoura-linux/.local/lib/python3.8/site-packages (from ipyparallel; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (4.62.3)
# Requirement already satisfied: psutil in /home/avmoura-linux/.local/lib/python3.8/site-packages (from ipyparallel; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (5.9.0)
# Requirement already satisfied: tornado>=5.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from ipyparallel; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (6.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from ipywidgets; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from ipywidgets; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: babel>=1.3 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (2.9.1)
# Requirement already satisfied: docutils<0.18,>=0.14 in /usr/local/lib/python3.8/dist-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (0.15.2)
# Requirement already satisfied: sphinxcontrib-applehelp in /home/avmoura-linux/.local/lib/python3.8/site-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /home/avmoura-linux/.local/lib/python3.8/site-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-devhelp in /home/avmoura-linux/.local/lib/python3.8/site-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.0.2)
# Requirement already satisfied: packaging in /home/avmoura-linux/.local/lib/python3.8/site-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (21.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (0.7.12)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in /home/avmoura-linux/.local/lib/python3.8/site-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.0.3)
# Requirement already satisfied: snowballstemmer>=1.1 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (2.2.0)
# Requirement already satisfied: imagesize in /home/avmoura-linux/.local/lib/python3.8/site-packages (from Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from notebook; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from notebook; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (0.11.0)
# Requirement already satisfied: prometheus-client in /home/avmoura-linux/.local/lib/python3.8/site-packages (from notebook; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (0.11.0)
# Requirement already satisfied: argon2-cffi in /home/avmoura-linux/.local/lib/python3.8/site-packages (from notebook; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (20.1.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from ipykernel; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0->-r requirements.txt (line 8)) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0->-r requirements.txt (line 8)) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/lib/python3/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0->-r requirements.txt (line 8)) (0.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: async-generator in /home/avmoura-linux/.local/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.10)
# Requirement already satisfied: nest-asyncio in /home/avmoura-linux/.local/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.5.1)
# Requirement already satisfied: webencodings in /home/avmoura-linux/.local/lib/python3.8/site-packages (from bleach->nbconvert; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (0.5.1)
# Requirement already satisfied: pytz>=2015.7 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from babel>=1.3->Sphinx>=1.3; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (2021.1)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /home/avmoura-linux/.local/lib/python3.8/site-packages (from terminado>=0.8.3->notebook; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/avmoura-linux/.local/lib/python3.8/site-packages (from argon2-cffi->notebook; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (1.14.6)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.8/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0->-r requirements.txt (line 8)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0->-r requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: pycparser in /home/avmoura-linux/.local/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook; extra == "all"->IPython[all]->-r requirements.txt (line 12)) (2.20)

# %%
#importando as bibliotecas necessarias

import cv2
import os
import numpy as np
import random
import colorsys
import argparse
import time
from mrcnn import model as modellib
from mrcnn import visualize
from coco.coco import CocoConfig
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# Using TensorFlow backend.

# %%
class MyConfig(CocoConfig): #sobrescrevendo as configuracoes do COCO com as minhas
    NAME = "my_coco_inference"
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

# %%
def prepare_mrcnn_model(model_path, model_name, class_names, my_config):
    classes = open(class_names).read().strip().split("\n")
    print("No. of classes", len(classes))

    hsv = [(i / len(classes), 1, 1.0) for i in range(len(classes))]
    COLORS = list(map(lambda c: colorsys.hsv_to_rgb(*c), hsv))
    random.seed(42)
    random.shuffle(COLORS) #separa a quantidade de cores necessarias

    model = modellib.MaskRCNN(mode="inference", model_dir=model_path, config=my_config) #instancia o Mask RCNN
    model.load_weights(model_name, by_name=True) #carregas os pesos ja treinados para dentro do modelo

    return COLORS, model, classes

# %%
def perform_inference_image(image_path, model, colors, classes, draw_bbox, instance_segmentation):
    test_image = cv2.imread(image_path)
    test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

    output = custom_visualize(test_image, model, colors, classes, draw_bbox, instance_segmentation)
    output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)

    return output

# %%
def custom_visualize(test_image, model, colors, classes, draw_bbox, instance_segmentation):
    detections = model.detect([test_image])[0]

    if instance_segmentation:
        hsv = [(i / len(detections['rois']), 1, 1.0) for i in range(len(detections['rois']))]
        colors = list(map(lambda c: colorsys.hsv_to_rgb(*c), hsv))
        random.seed(42)
        random.shuffle(colors)

    for i in range(0, detections["rois"].shape[0]):
        classID = detections["class_ids"][i]

        mask = detections["masks"][:, :, i]
        if instance_segmentation:
            color = colors[i][::-1]
        else:
            color = colors[classID][::-1]

        # To visualize the pixel-wise mask of the object
        test_image = visualize.apply_mask(test_image, mask, color, alpha=0.5)

    test_image = cv2.cvtColor(test_image, cv2.COLOR_RGB2BGR)
    
    if draw_bbox==True:
        for i in range(0, len(detections["scores"])):
            (startY, startX, endY, endX) = detections["rois"][i]

            classID = detections["class_ids"][i]
            label = classes[classID]
            score = detections["scores"][i]

            if instance_segmentation:
                color = [int(c) for c in np.array(colors[i]) * 255]

            else:
                color = [int(c) for c in np.array(colors[classID]) * 255]

            cv2.rectangle(test_image, (startX, startY), (endX, endY), color, 2)
            text = "{}: {:.2f}".format(label, score)
            y = startY - 10 if startY - 10 > 10 else startY + 10
            cv2.putText(test_image, text, (startX, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

            print("{},".format(text), end=" ")

    return test_image

# %%
model_path = "models/"; model_name = "models/mask_rcnn_coco.h5"; class_names = "coco/coco_classes.txt"; image = "./test_image.jpg"

my_config = MyConfig()
# my_config.display()

colors, model, classes = prepare_mrcnn_model(model_path, model_name, class_names, my_config)
output = perform_inference_image(image, model, colors, classes, draw_bbox = True, instance_segmentation = True)

# plt.imsave("result.png", output)
plt.imshow(output)
plt.show()
# Out:
# No. of classes 81
